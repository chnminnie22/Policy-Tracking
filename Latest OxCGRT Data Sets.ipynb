# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import requests

# %% [markdown]
# # Latest Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/OxCGRT_latest.csv', error_bad_lines=False)
usa = df[df['CountryCode'].str.contains('USA')]
usa
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 82186   United States         USA        NaN        NaN    NAT_TOTAL
# 82187   United States         USA        NaN        NaN    NAT_TOTAL
# 82188   United States         USA        NaN        NaN    NAT_TOTAL
# 82189   United States         USA        NaN        NaN    NAT_TOTAL
# 82190   United States         USA        NaN        NaN    NAT_TOTAL
# 82191   United States         USA        NaN        NaN    NAT_TOTAL
# 82192   United States         USA        NaN        NaN    NAT_TOTAL
# 82193   United States         USA        NaN        NaN    NAT_TOTAL
# 82194   United States         USA        NaN        NaN    NAT_TOTAL
# 82195   United States         USA        NaN        NaN    NAT_TOTAL
# 82196   United States         USA        NaN        NaN    NAT_TOTAL
# 82197   United States         USA        NaN        NaN    NAT_TOTAL
# 82198   United States         USA        NaN        NaN    NAT_TOTAL
# ...

# %% [markdown]
# # Latest Data with Notes/Sources

# %%
df_notes = pd.read_csv('https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/OxCGRT_latest_withnotes.csv', error_bad_lines=False)
usa_notes = df[df['CountryCode'].str.contains('USA')]
usa_notes
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 82186   United States         USA        NaN        NaN    NAT_TOTAL
# 82187   United States         USA        NaN        NaN    NAT_TOTAL
# 82188   United States         USA        NaN        NaN    NAT_TOTAL
# 82189   United States         USA        NaN        NaN    NAT_TOTAL
# 82190   United States         USA        NaN        NaN    NAT_TOTAL
# 82191   United States         USA        NaN        NaN    NAT_TOTAL
# 82192   United States         USA        NaN        NaN    NAT_TOTAL
# 82193   United States         USA        NaN        NaN    NAT_TOTAL
# 82194   United States         USA        NaN        NaN    NAT_TOTAL
# 82195   United States         USA        NaN        NaN    NAT_TOTAL
# 82196   United States         USA        NaN        NaN    NAT_TOTAL
# 82197   United States         USA        NaN        NaN    NAT_TOTAL
# 82198   United States         USA        NaN        NaN    NAT_TOTAL
# ...
